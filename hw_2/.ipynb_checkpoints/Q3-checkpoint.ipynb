# %%
from helper import Helper

x_train = Helper.load_csv('data/hw2p3_xtrain.csv')
y_train = Helper.load_csv('data/hw2p3_ytrain.csv')
x_test = Helper.load_csv('data/hw2p3_xtest.csv')

print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
# Out:
# (10, 49)
# (10, 49)
# (1000, 1)

# %%
# Out:
# pandas.core.frame.DataFrame

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

x = range(-5, 5)
y = range(-5, 5)

fig, ax = plt.subplots(nrows=7, ncols=7, figsize=(15, 15))
fig.subplots_adjust(wspace=0.5, hspace=0.5)

for row in ax:
    for col in row:
        col.set_xlim([-10, 10])
        col.set_xticks([-10, 0, 10])
        
        col.set_ylim([-10, 10])
        col.set_yticks([-10, 0, 10])
        
        col.plot(x, y, color='red')
        col.scatter([0,5,7], [-5, 8, 9], color='blue', s=np.full((3,), 1))

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-c12a76d26731> in <module>
#      18
#      19         col.plot(x, y, color='red')
# ---> 20         col.scatter([0,5,7], [-5, 8, 9], color='blue', s=np.fill(3, 1))
#      21
#      22 plt.show()
#
# AttributeError: module 'numpy' has no attribute 'fill'
