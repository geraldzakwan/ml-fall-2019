# %%
# type_dict = set([])
# x = 0
# for data_type in df['Description']:
#     type_dict.add(data_type)
#     if 'numeric' in data_type:
#         x = x + 1
        
# print(x)

# %%
import pandas as pd
from collections import defaultdict

df = pd.read_csv('CodeBook-SELECT.csv')

excluded = []
for i in range(0, 377):
    desc = df.iloc[i]['Description'] 
    varname = df.iloc[i]['VarName']
    
    if 'ISCO' in desc or 'ISCO' in varname:
        excluded.append(varname)
        
    elif 'ISIC' in desc or 'ISIC' in varname:
        excluded.append(varname)

    elif 'mth' in desc or 'mth' in varname:
        excluded.append(varname)
        
    elif 'coded' in desc or 'coded' in varname:
        excluded.append(varname)

# %%
import pandas as pd
import numpy as np
# %matplotlib inline

df = pd.read_csv('hw4-trainingset-gd2551.csv')
df = df.drop(['uni', 'row'] + excluded, axis=1)
# df = df.drop(df[df.gender_r == 'Male'].sample(frac=.4).index)
# df.hist(column='job_performance')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3044: DtypeWarning: Columns (50,172,255,256,257,258,268,280,376) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
print('ALL COLUMNS')
print(len(df.columns))

df = df.fillna(df.mode().iloc[0])

# Find numeric ones
num_col = []
for col in df.columns:
    if np.issubdtype(df[col].dtype, np.number):
        num_col.append(col)

print('NUM COL')
print(len(num_col))

# print(df[num_col[0:8]].mean())
# print(df[num_col[8:16]].mean())
# print(df[num_col[16:24]].mean())
# print(df[num_col[24:32]].mean())
# print(df[num_col[32:40]].mean())
# print(df[num_col[40:48]].mean())
# print(df[num_col[48:56]].mean())
# print(df[num_col[56:64]].mean())
# print(df[num_col[64:72]].mean())
# print(df[num_col[72:80]].mean())
# print(df[num_col[80:84]].mean())

incl_num_cols = []
for col in num_col:
    if not df[col].isna().sum() > 10000:
        m = df[col].mean()
#         if m >= 1.0:
#             if not (m > 9000.0 and m < 10000.0):
#                 incl_num_cols.append(col)
                
#                 if m > 1990.0 and m < 2020.0:
#                     df[col] = df[col] - 1990.0
        if m > 1990.0 and m < 2020.0:
            df[col] = df[col] - 1990.0
        incl_num_cols.append(col)

print('INCL COL')
print(len(incl_num_cols))

print(df[incl_num_cols[0:8]].mean())
print(df[incl_num_cols[8:16]].mean())
print(df[incl_num_cols[16:24]].mean())
print(df[incl_num_cols[24:32]].mean())
print(df[incl_num_cols[32:40]].mean())
print(df[incl_num_cols[40:48]].mean())
print(df[incl_num_cols[48:56]].mean())
print(df[incl_num_cols[56:64]].mean())
print(df[incl_num_cols[64:72]].mean())
print(df[incl_num_cols[72:80]].mean())
print(df[incl_num_cols[80:84]].mean())
# Out:
# ALL COLUMNS
# 343
# NUM COL
# 60
# INCL COL
# 59
# age_r        35.658750
# yrsqual      14.757775
# yrsget       14.885500
# imyrs        10.325250
# leavedu      22.816550
# nfehrsnjr    19.184050
# nfehrsjr     70.076450
# nfehrs       99.925900
# dtype: float64
# earnhr             998.846943
# earnhrppp           24.171067
# earnhrbonus       1095.568602
# earnhrbonusppp      14.064605
# learnatwork          2.525914
# readytolearn         2.460732
# icthome              2.470036
# ictwork              2.662157
# dtype: float64
# influence             2.559651
# planning              2.344283
# readhome              2.578578
# readwork              2.754459
# taskdisc              2.428656
# writhome              2.327348
# writwork              2.682178
# job_performance    2909.906533
# dtype: float64
# v202    20.86910
# v231    20.91700
# v272    10.28980
# v78      0.40940
# v196    21.27205
# v61      7.72375
# v129     6.01345
# v268     1.00485
# dtype: float64
# v206     1.21080
# v207     1.81030
# v136     1.65635
# v194     1.10880
# v283     2.98100
# v145     6.80005
# v41     25.93250
# v45      1.05555
# dtype: float64
# v110    51.97860
# v160    19.99195
# v52     18.21075
# v33      1.52440
# v184    27.15980
# v104    16.72335
# v22     34.81490
# v241    19.21340
# dtype: float64
# v135    4.352405e+01
# v100    3.331427e+00
# v63     5.138832e+02
# v87     1.094969e+06
# v210    2.081282e+05
# v169    6.260642e+05
# v113    2.217330e+01
# v130    1.981950e+01
# dtype: float64
# v215    28.99745
# v163    19.97790
# v81     40.09150
# dtype: float64
# Series([], dtype: float64)
# Series([], dtype: float64)
# Series([], dtype: float64)

# %%
def oneHotEncode(df,colNames):
    print(len(colNames))
    iter = 0
    new_cols = []
    for col in colNames:
        if( df[col].dtype == np.dtype('object')):
            dummies = pd.get_dummies(df[col],prefix=col)
            new_cols = new_cols + dummies.columns.tolist()
            df = pd.concat([df,dummies],axis=1)
            #drop the encoded column
            df.drop([col],axis = 1 , inplace=True)
            
            iter = iter + 1
            if (iter % 100 == 0):
                print(iter)
    return df, new_cols

# %%
# Remove 999?

cat_col = list(set(df.columns).difference(set(incl_num_cols)))
# for col in cat_col:
#     df[col] = df[col].astype('category').cat.codes
    
print('CAT COL')
print(len(cat_col))

incl_cat_cols = []
for col in cat_col:
#     if len(df[col].unique()) < 11:
#         incl_cat_cols.append(col)
    incl_cat_cols.append(col)

print('INCL COL')
print(len(incl_num_cols))

print('There were {} columns before encoding categorical features'.format(df.shape[1]))
df, incl_cat_cols = oneHotEncode(df, incl_cat_cols)
print('There are {} columns after encoding categorical features'.format(df.shape[1]))

# iter = 0
# for col in cat_col:
#     iter = iter + 1
#     print(df[col].unique())
    
# print(iter)
# print(df[incl_num_cols[8:16]].mean())
# print(df[incl_num_cols[16:24]].mean())
# print(df[incl_num_cols[24:32]].mean())
# print(df[incl_num_cols[32:40]].mean())
# print(df[incl_num_cols[40:48]].mean())
# print(df[incl_num_cols[48:56]].mean())
# print(df[incl_num_cols[56:64]].mean())
# print(df[incl_num_cols[64:72]].mean())
# print(df[incl_num_cols[72:80]].mean())
# print(df[incl_num_cols[80:84]].mean())

# import sys
# sys.exit()
# Out:
# CAT COL
# 284
# INCL COL
# 59
# There were 343 columns before encoding categorical features
# 284
# 100
# 200
# There are 1427 columns after encoding categorical features

# %%
import pickle

sampling_percentage = 40
dropped_indexes = df[df['gender_r_Male'] == 1].sample(frac=float(sampling_percentage/100)).index
print(float(sampling_percentage/100))
print(dropped_indexes)
with open('dropped_indexes_' + str(sampling_percentage) + '.pickle', 'wb') as outfile:
    # dump information to that file
    pickle.dump(dropped_indexes, outfile)

# with open('dropped_indexes_' + '40_77473' + '.pickle', 'rb') as infile:
#     # dump information to that file
#     dropped_indexes = pickle.load(infile)

train_df = df.drop(dropped_indexes)
print(len(train_df))
print(len(train_df.columns))
train_df = train_df[incl_num_cols + incl_cat_cols]

df = df[incl_num_cols + incl_cat_cols]
print(len(df))
print(len(df.columns))

# labels = df['job_performance']
# df = df.drop(['job_performance'], axis=1)
# train_df = train_df.drop(['job_performance'], axis=1)
# Out:
# 0.4
# Int64Index([ 1856, 15840, 14779,  3130, 14636,  3276,  9021,  8729,  6975,
#              6669,
#             ...
#             14200,  4816,  9342,   192, 19711, 13669, 15479,  7341,  3956,
#             11744],
#            dtype='int64', length=4998)
# 15002
# 1427
# 20000
# 1425

# %%
import numpy as np
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import PolynomialFeatures


# Split the data into training/testing sets
X_train = train_df.drop(['job_performance'], axis=1).values
y_train = train_df['job_performance'].values

# gbm = xgb.XGBClassifier(max_depth=3, n_estimators=300, learning_rate=0.05).fit(X_train, y_train)
# y_pred = gbm.predict(X_train)

# Create linear regression object
clf = linear_model.LinearRegression()
# clf = linear_model.Lasso(alpha=0.1)

# Train the model using the training sets
clf.fit(X_train, y_train)

X_train = df.drop(['job_performance'], axis=1).values
y_train = df['job_performance'].values

y_pred = clf.predict(X_train)

mean_squared_error(y_train, y_pred)
# Out:
# 73797.33938138091

# %%
y_train[0:10]
# Out:
# array([2496.02548403, 3072.47145243, 3286.83878409, 3067.76092539,
#        2394.30356909, 2072.3991696 , 2152.94455608, 2068.94502318,
#        3259.1151392 , 3120.18034233])

# %%
y_pred[0:10]
# Out:
# array([2656.96159971, 2763.65261544, 3385.74138556, 2778.76918324,
#        2886.60818776, 2208.82789621, 2714.53617391, 2419.96042017,
#        3044.7756484 , 3093.20037539])

# %%
# feat_idx = np.where(clf.coef_ > 0)
# feat_idx

# %%
# df.columns[feat_idx]

# %%
# # Split the data into training/testing sets
# y_train = train_df['job_performance'].values
# X_train = train_df[train_df.columns[feat_idx]].values

# # poly = PolynomialFeatures(3)
# # poly.fit_transform(X_train)

# # gbm = xgb.XGBClassifier(max_depth=3, n_estimators=300, learning_rate=0.05).fit(X_train, y_train)
# # y_pred = gbm.predict(X_train)

# # Create linear regression object
# clf = linear_model.LinearRegression()
# # clf = linear_model.Lasso(alpha=0.1)

# # Train the model using the training sets
# clf.fit(X_train, y_train)

# y_train = df['job_performance'].values
# X_train = df[df.columns[feat_idx]].values

# # poly = PolynomialFeatures(3)
# # poly.fit_transform(X_train)

# y_pred = clf.predict(X_train)

# mean_squared_error(y_train, y_pred)

# %% [markdown]
# Note:
#
# 0.4 Dropped Samples for Men <br>
# Lasso 0.1 <br>
# Include categorical variable which accounts for 10 category or less <br>
# Result: 78483.30285504548 -> Sabiii ini udh against all train data (include random noise) <br>
#
# Kalo abis Lasso diambil yg pentingnya trus di LinReg lagi hasilnya jadi 99105, jelek
#
# 0.4 Dropped Samples for Men <br>
# LinReg <br>
# Include categorical variable which accounts for 10 category or less <br>
# Result: 77535.61922625062 -> Sabiii ini udh against all train data (include random noise) <br>
#
# 1.0 Sampling for Men <br>
# LinReg <br>
# Include categorical variable which accounts for 10 category or less <br>
# Result: 75436.67962546097 -> Sabiii ini udh against all train data (include random noise) <br>

# %%
train_df = pd.read_csv('hw4-trainingset-gd2551.csv')
train_df[incl_num_cols].mean()
# Out:
# age_r              3.933941e+01
# yrsqual            1.457355e+01
# yrsget             1.457106e+01
# imyrs              1.889877e+01
# leavedu            2.348978e+01
# nfehrsnjr          3.944495e+01
# nfehrsjr           1.018412e+02
# nfehrs             1.395034e+02
# earnhr             2.371231e+03
# earnhrppp          2.023497e+01
# earnhrbonus        2.617036e+03
# earnhrbonusppp     2.187353e+01
# learnatwork        2.278334e+00
# readytolearn       2.458547e+00
# icthome            2.415287e+00
# ictwork            2.665242e+00
# influence          2.519561e+00
# planning           2.313076e+00
# readhome           2.565938e+00
# readwork           2.750616e+00
# taskdisc           2.307034e+00
# writhome           2.321842e+00
# writwork           2.662648e+00
# job_performance    2.909907e+03
# v202               2.274977e+01
# v231               2.276790e+01
# v272               1.994882e+03
# v78                9.532014e+00
# v196               2.374937e+01
# v61                1.995277e+03
# v129               8.988889e+00
# v268               1.283626e+00
# v206               2.886353e+00
# v207               3.534167e+00
# v136               3.298949e+00
# v194               2.266589e+00
# v283               9.462914e+00
# v145               1.168542e+01
# v41                4.943438e+01
# v45                4.277286e+00
# v110               4.227273e+01
# v160               2.006422e+03
# v52                1.710875e+01
# v33                1.846352e+00
# v184               2.971624e+01
# v104               2.001898e+03
# v22                3.290847e+01
# v241               2.001337e+03
# v135               4.403694e+01
# v100               1.503011e+02
# v63                7.452878e+02
# v87                2.792257e+06
# v210               8.986570e+05
# v169               9.759379e+06
# v113               2.839483e+01
# v130               2.003554e+03
# v215               2.820312e+01
# v163               2.003200e+03
# v81                4.184848e+01
# dtype: float64

# %%
test_df = pd.read_csv('hw4-testset-gd2551.csv')
test_df[incl_num_cols].mean()
# Out:
# age_r              3.988279e+01
# yrsqual            1.231951e+01
# yrsget             1.245346e+01
# imyrs              1.924202e+01
# leavedu            2.067142e+01
# nfehrsnjr          6.211541e+01
# nfehrsjr           9.279689e+01
# nfehrs             1.582147e+02
# earnhr             1.701177e+03
# earnhrppp          1.412181e+01
# earnhrbonus        1.817573e+03
# earnhrbonusppp     1.496619e+01
# learnatwork        1.998742e+00
# readytolearn       1.974189e+00
# icthome            1.915152e+00
# ictwork            1.962691e+00
# influence          2.015808e+00
# planning           1.946935e+00
# readhome           1.993261e+00
# readwork           2.018824e+00
# taskdisc           1.995851e+00
# writhome           2.008285e+00
# writwork           2.076346e+00
# job_performance             NaN
# v202               1.999690e+01
# v231               2.000238e+01
# v272               1.991855e+03
# v78                9.294458e+00
# v196               2.148872e+01
# v61                1.992549e+03
# v129               9.349057e+00
# v268               1.277567e+00
# v206               2.512727e+00
# v207               3.001297e+00
# v136               2.991413e+00
# v194               1.985328e+00
# v283               1.215126e+01
# v145               1.240432e+01
# v41                5.004465e+01
# v45                9.923288e+00
# v110               4.044316e+01
# v160               2.003468e+03
# v52                1.716235e+01
# v33                1.862726e+00
# v184               3.095041e+01
# v104               2.002411e+03
# v22                3.302920e+01
# v241               1.999877e+03
# v135               3.921853e+01
# v100               5.584451e+01
# v63                4.967655e+02
# v87                1.058176e+06
# v210               4.820924e+05
# v169               7.388636e+06
# v113               3.096689e+01
# v130               2.002752e+03
# v215               3.414493e+01
# v163               1.997717e+03
# v81                3.704005e+01
# dtype: float64

# %%
for col in incl_num_cols:
    print(train_df[col].mean())
    print(test_df[col].mean())
    print('--------------------')
# Out:
# 39.339412444297736
# 39.88279442116455
# --------------------
# 14.57354883160131
# 12.319506521937425
# --------------------
# 14.571062247579974
# 12.45345588235294
# --------------------
# 18.89876880984952
# 19.242021276595743
# --------------------
# 23.48978288633461
# 20.671418974397252
# --------------------
# 39.444947054590315
# 62.11540507675939
# --------------------
# 101.84116377094685
# 92.796891624867
# --------------------
# 139.50336239103362
# 158.2147491349481
# --------------------
# 2371.2314624415067
# 1701.1765139332445
# --------------------
# 20.23496976595765
# 14.121810983116033
# --------------------
# 2617.035776191072
# 1817.5733653384816
# --------------------
# 21.873532165814037
# 14.966185118668909
# --------------------
# 2.2783342200708803
# 1.998742385873419
# --------------------
# 2.4585469004441904
# 1.9741887931575233
# --------------------
# 2.4152868150202456
# 1.9151521916040277
# --------------------
# 2.665241655024839
# 1.9626908992345315
# --------------------
# 2.5195613412385325
# 2.0158076772204905
# --------------------
# 2.313076357349257
# 1.9469346663915617
# --------------------
# 2.565938361723551
# 1.993261222262627
# --------------------
# 2.7506156723234882
# 2.018823795425429
# --------------------
# 2.3070341043955347
# 1.9958511075494902
# --------------------
# 2.321841548819858
# 2.008285240598097
# --------------------
# 2.662648028416587
# 2.0763456033054566
# --------------------
# 2909.9065328638526
# nan
# --------------------
# 22.749772369836933
# 19.99689842336521
# --------------------
# 22.767898005884277
# 20.0023766700925
# --------------------
# 1994.8818380743983
# 1991.8552421160366
# --------------------
# 9.532013969732247
# 9.294458229942101
# --------------------
# 23.749368367862555
# 21.48872180451128
# --------------------
# 1995.2769837358305
# 1992.549394221808
# --------------------
# 8.988888888888889
# 9.349056603773585
# --------------------
# 1.2836257309941521
# 1.2775665399239544
# --------------------
# 2.8863534675615212
# 2.5127272727272727
# --------------------
# 3.5341673182173574
# 3.0012966804979255
# --------------------
# 3.2989492119089316
# 2.9914134742404226
# --------------------
# 2.2665890570430736
# 1.9853281853281852
# --------------------
# 9.462913655382275
# 12.15126484254001
# --------------------
# 11.685422469823584
# 12.404323692667251
# --------------------
# 49.43438352766063
# 50.04464973056197
# --------------------
# 4.277286135693215
# 9.923287671232877
# --------------------
# 42.27272727272727
# 40.443155452436194
# --------------------
# 2006.4222222222222
# 2003.4683127572016
# --------------------
# 17.108750100993777
# 17.162353445810695
# --------------------
# 1.8463524854744997
# 1.8627260981912144
# --------------------
# 29.716235396877387
# 30.950409062303336
# --------------------
# 2001.897839736086
# 2002.4113132813468
# --------------------
# 32.90847457627119
# 33.02920227920228
# --------------------
# 2001.3370044052863
# 1999.8767507002801
# --------------------
# 44.03694369666075
# 39.218533709305305
# --------------------
# 150.30111111111108
# 55.84450980392156
# --------------------
# 745.2878015613196
# 496.76550766456273
# --------------------
# 2792257.23834662
# 1058176.3906181937
# --------------------
# 898656.975574785
# 482092.44586065586
# --------------------
# 9759378.939984411
# 7388635.823053589
# --------------------
# 28.394833948339482
# 30.9668911335578
# --------------------
# 2003.5535714285713
# 2002.7516666666668
# --------------------
# 28.203125
# 34.14492753623188
# --------------------
# 2003.2
# 1997.7173913043478
# --------------------
# 41.84848484848485
# 37.040049291435615
# --------------------

# %%
train_df = pd.read_csv('hw4-trainingset-gd2551.csv')

sampling_percentage = 40
dropped_indexes = train_df[train_df['gender_r'] == 'Male'].sample(frac=float(sampling_percentage/100), random_state=28).index
train_df = train_df.drop(dropped_indexes)
len(train_df)
# Out:
# 15002

# %%
for col in incl_num_cols:
    print(train_df[col].mean())
    print(test_df[col].mean())
    print('--------------------')
# Out:
# 39.090799031477
# 39.88279442116455
# --------------------
# 14.614865894544346
# 12.319506521937425
# --------------------
# 14.573294445853412
# 12.45345588235294
# --------------------
# 18.921818181818182
# 19.242021276595743
# --------------------
# 23.484229828850857
# 20.671418974397252
# --------------------
# 41.298639878486604
# 62.11540507675939
# --------------------
# 99.90309997238332
# 92.796891624867
# --------------------
# 140.2609715242881
# 158.2147491349481
# --------------------
# 2145.1533022536705
# 1701.1765139332445
# --------------------
# 19.756769179328604
# 14.121810983116033
# --------------------
# 2355.418032417973
# 1817.5733653384816
# --------------------
# 21.27720726321686
# 14.966185118668909
# --------------------
# 2.273708772850256
# 1.998742385873419
# --------------------
# 2.4460834173181953
# 1.9741887931575233
# --------------------
# 2.393896625346538
# 1.9151521916040277
# --------------------
# 2.6483239649461163
# 1.9626908992345315
# --------------------
# 2.500984253178856
# 2.0158076772204905
# --------------------
# 2.297437296379848
# 1.9469346663915617
# --------------------
# 2.543755159244384
# 1.993261222262627
# --------------------
# 2.7245290495277046
# 2.018823795425429
# --------------------
# 2.2611473354978093
# 1.9958511075494902
# --------------------
# 2.3176022448417544
# 2.008285240598097
# --------------------
# 2.654505162235756
# 2.0763456033054566
# --------------------
# 2891.638857793095
# nan
# --------------------
# 22.805675168378052
# 19.99689842336521
# --------------------
# 22.81672481465329
# 20.0023766700925
# --------------------
# 1995.1831945495837
# 1991.8552421160366
# --------------------
# 9.571646341463415
# 9.294458229942101
# --------------------
# 23.776853776853777
# 21.48872180451128
# --------------------
# 1995.4776725304466
# 1992.549394221808
# --------------------
# 9.016129032258064
# 9.349056603773585
# --------------------
# 1.253968253968254
# 1.2775665399239544
# --------------------
# 2.916971916971917
# 2.5127272727272727
# --------------------
# 3.51931330472103
# 3.0012966804979255
# --------------------
# 3.2945550491724633
# 2.9914134742404226
# --------------------
# 2.076569678407351
# 1.9853281853281852
# --------------------
# 9.661290322580646
# 12.15126484254001
# --------------------
# 11.729113924050633
# 12.404323692667251
# --------------------
# 51.41647745702238
# 50.04464973056197
# --------------------
# 3.897338403041825
# 9.923287671232877
# --------------------
# 39.096774193548384
# 40.443155452436194
# --------------------
# 2005.8064516129032
# 2003.4683127572016
# --------------------
# 16.770399913765225
# 17.162353445810695
# --------------------
# 1.8507478747444313
# 1.8627260981912144
# --------------------
# 29.676339606378395
# 30.950409062303336
# --------------------
# 2002.0960515261831
# 2002.4113132813468
# --------------------
# 32.93917274939173
# 33.02920227920228
# --------------------
# 2001.3167456556082
# 1999.8767507002801
# --------------------
# 43.34406130268199
# 39.218533709305305
# --------------------
# 122.01833333333335
# 55.84450980392156
# --------------------
# 718.9255845866726
# 496.76550766456273
# --------------------
# 2367524.5002326495
# 1058176.3906181937
# --------------------
# 777327.1829598593
# 482092.44586065586
# --------------------
# 10057169.366213152
# 7388635.823053589
# --------------------
# 28.28095238095238
# 30.9668911335578
# --------------------
# 2004.3402777777778
# 2002.7516666666668
# --------------------
# 27.565217391304348
# 34.14492753623188
# --------------------
# 2002.7173913043478
# 1997.7173913043478
# --------------------
# 41.18028534370947
# 37.040049291435615
# --------------------

# %%
x_col = []
for col in train_df:
    if np.issubdtype(train_df[col].dtype, np.number):
        y = train_df[col][train_df[col] >= 9990]
        if len(y) > 0:
            z = train_df[col][train_df[col] <= 9999]
            if len(z) > 0:
                x_col.append(col)

# %%
x_col
# Out:
# ['isco1c',
#  'isco2c',
#  'isco1l',
#  'isco2l',
#  'earnhr',
#  'earnhrbonus',
#  'earnmth',
#  'earnmthppp',
#  'earnmthselfppp',
#  'earnmthbonus',
#  'earnmthall',
#  'earnmthallppp',
#  'earnmthbonusppp',
#  'v87',
#  'v210',
#  'v169',
#  'v239',
#  'v224',
#  'v105']

# %%
train_df['lng_home'].unique()
# Out:
# array(['999', 'fin', 'spa', 'eng', 'ara', 'kor', 'fra', 'ron', 'jpn',
#        'heb', 'lit', 'por', 'deu', 'ces', 'nld', 'ell', 'eus', 'slk',
#        'pol', 'est', 'dan', 'cat', 'srp', 'nor', 'urd', 'slv', 'hun',
#        'tur', 'sin', 'swe', 'phi', nan, 'rus', 'ita', 'glg', 'sla', 'tam',
#        'hin', 'ber', '997', 'gla', 'guj', 'isl', 'hye', 'hrv', 'kur',
#        'fas', 'bul', 'zho', 'run', 'ben'], dtype=object)
